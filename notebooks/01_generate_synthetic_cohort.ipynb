# %% [markdown]
# # 01 · Generate the synthetic cohort
#
# Build a small synthetic cohort, validate its schema, and inspect the regime distribution.

# %%
import sys, warnings
from pathlib import Path
warnings.filterwarnings('ignore')
REPO_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(REPO_ROOT / 'src'))
import numpy as np; import pandas as pd; import matplotlib.pyplot as plt

# %%
from data.synthetic_generator import generate_synthetic_cohort
from data.validation import validate_cohort

cohort = generate_synthetic_cohort(n_participants=50, n_days=120, seed=17)
print(cohort.shape)
cohort.head()

# %% [markdown]
# ## Validate schema and value ranges

# %%
validate_cohort(cohort)
print('Validation passed.')

# %% [markdown]
# ## Regime distribution

# %%
cohort['regime_label'].value_counts()

# %%
fig, ax = plt.subplots(figsize=(6, 3))
cohort['regime_label'].value_counts().plot(kind='bar', ax=ax)
ax.set_ylabel('person-days'); ax.set_title('Regime distribution')
plt.tight_layout(); plt.show()
